# %% [markdown]
# ## Import Libraries

# %%
from hdp_data_import import import_heart_disease_data
from data_analysis import *

# %% [markdown]
# ## Import Data

# %%
X_train, X_test, y_train, y_test = import_heart_disease_data()

# %%
train_data = pd.concat([X_train, y_train], axis=1)

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# ### All variables

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 644 entries, 0 to 643
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             644 non-null    float64
#  1   sex             644 non-null    float64
#  2   cp              644 non-null    float64
#  3   trestbps        605 non-null    float64
#  4   chol            622 non-null    float64
#  5   fbs             581 non-null    float64
#  6   restecg         643 non-null    float64
#  7   thalach         608 non-null    float64
#  8   exang           608 non-null    float64
#  9   oldpeak         602 non-null    float64
#  10  slope           428 non-null    float64
#  11  ca              224 non-null    float64
#  12  thal            314 non-null    float64
#  13  disease_degree  644 non-null    int64
# dtypes: float64(13), int64(1)
# memory usage: 70.6 KB

# %% [markdown]
# Only ca and thal columns have null values.

# %%
train_data.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  644.000000  644.000000  644.000000  605.000000  622.000000  581.000000
# mean    53.403727    0.793478    3.273292  132.593388  198.075563    0.161790
# std      9.366483    0.405124    0.914630   19.695697  111.730924    0.368575
# min     28.000000    0.000000    1.000000    0.000000    0.000000    0.000000
# 25%     47.000000    1.000000    3.000000  120.000000  175.000000    0.000000
# 50%     54.000000    1.000000    4.000000  130.000000  223.000000    0.000000
# 75%     60.000000    1.000000    4.000000  142.000000  267.000000    0.000000
# max     77.000000    1.000000    4.000000  200.000000  603.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  643.000000  608.000000  608.000000  602.000000  428.000000  224.000000
# mean     0.597201  137.745066    0.386513    0.876744    1.768692    0.709821
# ...

# %%
plot_correlations(train_data)

# %% [markdown]
# ### By variable: univariate and multivariate comparing with target

# %% [markdown]
# #### - age
#
# Unit: years

# %%
continuous_univariate_analysis(train_data, "age")

# %%
multivariate_analysis(train_data, "age")

# %% [markdown]
# #### - sex
#
# Sex (1 = male; 0 = female)

# %%
categorical_univariate_analysis(train_data, "sex")

# %%
multivariate_analysis(train_data, "sex")

# %% [markdown]
# #### - cp
#
# Chest pain type -- Value 1: typical angina -- Value 2: atypical angina -- Value 3: non-anginal pain -- Value 4: asymptomatic

# %%
categorical_univariate_analysis(train_data, "cp")

# %%
multivariate_analysis(train_data, "cp")

# %% [markdown]
# #### - trestbps
#
# Resting blood pressure (in mm Hg on admission to the hospital)

# %%
continuous_univariate_analysis(train_data, "trestbps")

# %%
multivariate_analysis(train_data, "trestbps")

# %% [markdown]
# #### - chol
#
# Serum cholestoral in mg/dl

# %%
continuous_univariate_analysis(train_data, "chol")

# %%
multivariate_analysis(train_data, "chol")

# %% [markdown]
# #### - fbs
#
# Fasting blood sugar > 120 mg/dl (1 = true; 0 = false)

# %%
categorical_univariate_analysis(train_data, "fbs")

# %%
multivariate_analysis(train_data, "fbs")

# %% [markdown]
# #### - restecg
#
# Resting electrocardiographic results -- Value 0: normal -- Value 1: having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV) -- Value 2: showing probable or definite left ventricular hypertrophy by Estes' criteria

# %%
categorical_univariate_analysis(train_data, "restecg")

# %%
multivariate_analysis(train_data, "restecg")

# %% [markdown]
# #### - thalach
#
# Maximum heart rate achieved

# %%
continuous_univariate_analysis(train_data, "thalach")

# %%
multivariate_analysis(train_data, "thalach")

# %% [markdown]
# #### - exang
#
# Exercise induced angina (1 = yes; 0 = no)

# %%
categorical_univariate_analysis(train_data, "exang")

# %%
multivariate_analysis(train_data, "exang")

# %% [markdown]
# #### - oldpeak

# %% [markdown]
# ST depression induced by exercise relative to rest

# %%
continuous_univariate_analysis(train_data, "oldpeak")

# %%
multivariate_analysis(train_data, "oldpeak")

# %% [markdown]
# #### - slope
#
# The slope of the peak exercise ST segment -- Value 1: upsloping -- Value 2: flat -- Value 3: downsloping

# %%
categorical_univariate_analysis(train_data, "slope")

# %%
multivariate_analysis(train_data, "slope")

# %% [markdown]
# #### - ca
#
# Number of major vessels (0-3) colored by flourosopy

# %%
categorical_univariate_analysis(train_data, "ca")

# %%
multivariate_analysis(train_data, "ca")

# %% [markdown]
# #### - thal
#
# 3 = normal; 6 = fixed defect; 7 = reversable defect

# %%
categorical_univariate_analysis(train_data, "thal")

# %%
multivariate_analysis(train_data, "thal")

# %% [markdown]
# #### - disease_degree

# %%
categorical_univariate_analysis(train_data, "disease_degree")

# %% [markdown]
# The dataset is clearly imbalanced. There is more of the class 0 (no disease) than any other classes.
